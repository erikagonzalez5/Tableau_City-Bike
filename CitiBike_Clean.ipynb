# %%
# Importing Dependencies
import pandas as pd
import numpy as np

# %%
bike1 = pd.read_csv("Resources/201912-citibike-tripdata.csv")
# bike2 = pd.read_csv("Resources/202002-citibike-tripdata.csv")
# bike3 = pd.read_csv("Resources/202003-citibike-tripdata.csv")
# bike4 = pd.read_csv("Resources/202004-citibike-tripdata.csv")
# bike5 = pd.read_csv("Resources/202005-citibike-tripdata.csv")
# bike6 = pd.read_csv("Resources/202006-citibike-tripdata.csv")
# bike7 = pd.read_csv("Resources/202007-citibike-tripdata.csv")
# bike8 = pd.read_csv("Resources/202008-citibike-tripdata.csv")
# bike9 = pd.read_csv("Resources/202009-citibike-tripdata.csv")
# bike10 = pd.read_csv("Resources/202010-citibike-tripdata.csv")
# bike11 = pd.read_csv("Resources/202011-citibike-tripdata.csv")
bike12 = pd.read_csv("Resources/202012-citibike-tripdata.csv")

# %%
citibike_2020_2021 = pd.concat([bike1, bike2, bike4, bike5, bike6, bike7, bike11, bike12])
citibike_2020_2021

# %%
citibike_2020_2021.dropna(how='all')

# %%
# Push the remade DataFrame to a new CSV file
citibike_2020_2021.to_csv("Resources/citibike_2020_2021.csv",
                  encoding="utf-8", index=False, header=True)

# %%
citibike_3 = pd.concat([bike10, bike11, bike12])
citibike_3
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1403  2020-10-01 00:00:10.7870  2020-10-01 00:23:34.5400
# 1                 462  2020-10-01 00:00:18.2390  2020-10-01 00:08:00.5710
# 2                 770  2020-10-01 00:00:21.3070  2020-10-01 00:13:12.0840
# 3                 233  2020-10-01 00:00:25.0080  2020-10-01 00:04:18.6410
# 4                 126  2020-10-01 00:00:25.3100  2020-10-01 00:02:32.1330
# ...               ...                       ...                       ...
# 1088924          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 1088925           288  2020-12-31 23:58:37.8400  2021-01-01 00:03:26.3250
# 1088926           152  2020-12-31 23:58:52.8090  2021-01-01 00:01:25.6720
# 1088927           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
# 1088928          2589  2020-12-31 23:59:57.4070  2021-01-01 00:43:06.4490
#
#          start station id                   start station name  \
# ...

# %%
# Push the remade DataFrame to a new CSV file
citibike_3.to_csv("Resources/citibike_correct.csv",
                  encoding="utf-8", index=False, header=True)

# %%
merged_bike = pd.concat([bike1, bike12])
merged_bike
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1                1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2                 723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3                 404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4                1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
# ...               ...                       ...                       ...
# 1088924          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 1088925           288  2020-12-31 23:58:37.8400  2021-01-01 00:03:26.3250
# 1088926           152  2020-12-31 23:58:52.8090  2021-01-01 00:01:25.6720
# 1088927           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
# 1088928          2589  2020-12-31 23:59:57.4070  2021-01-01 00:43:06.4490
#
#          start station id                   start station name  \
# ...

# %%
# Push the remade DataFrame to a new CSV file
merged_bike.to_csv("Resources/citibike_fin.csv",
                  encoding="utf-8", index=False, header=True)
